# %%
import requests
from bs4 import BeautifulSoup

# 設置PTT雅房版的URL模板
url_template = 'https://www.ptt.cc/bbs/Rent_ya/index{}.html'
ptt_url = 'https://www.ptt.cc'

# 建立一個Session物件以處理PTT的年齡認證
session = requests.Session()
payload = {'from': url_template.format(''), 'yes': 'yes'}
session.post('https://www.ptt.cc/ask/over18', data=payload)

# 今天想要找大安區的雅房，因此設立關鍵字"大安"
keyword = "大安"

# 建立一個空的清單用於儲存匹配的帖子
matched_posts = []

# 從最新頁面往前遍歷前23頁內容
for page in range(1, 24):
    url = url_template.format(page)
    
    # 發送GET請求並取得頁面內容
    response = session.get(url)

    if response.status_code == 200:
        # 使用Beautiful Soup解析頁面內容
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # 找到貼文的元素，通常它們有一個特定的class
        posts = soup.find_all(class_='r-ent')

        # 遍歷帖子元素並提取訊息
        for post in posts:
            title_elem = post.find(class_='title')
            title = title_elem.text.strip()
            
            # 檢查貼文標題是否包含關鍵字且不包含"男"
            if keyword in title and "男" not in title:
                # 取得文章編號
                post_id = title_elem.find('a')['href'].split('/')[-1].split('.')[0]
                # 構建完整的網址
                post_url = ptt_url + title_elem.find('a')['href']
                
                # 將匹配的帖子資料存入清單，僅當標題是唯一的時候
                if title not in [d['Title'] for d in matched_posts]:
                    print(f'Title: {title}')
                    print(f'Author: {post.find(class_="author").text}')
                    print(f'Date: {post.find(class_="date").text}')
                    print(f'URL: {post_url}')
                    print('\n')

                    matched_posts.append({'Title': title, 'Author': post.find(class_='author').text, 'Date': post.find(class_='date').text, 'URL': post_url})
    
    # 如果回應是 404，表示該頁面不存在，停止迴圈
    elif response.status_code == 404:
        break

    else:
        print(f'Failed to retrieve page {page}. Status code:', response.status_code)
# Out:
# Title: [徵/新北/新店] 板橋、文山、中正、大安皆可
# Author: lingmygt
# Date:  2/18
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1676720086.A.434.html
#
#
# Title: [無/台北/大安] 師大泰順街乾淨便利公寓雅房
# Author: eva79528
# Date:  2/27
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1677470835.A.108.html
#
#
# Title: [無/台北/大安] 近師大夜市家庭式雅房
# Author: bxzz
# Date:  3/08
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1678279070.A.B57.html
#
#
# Title: [女/台北/大安] 雅房出租
# Author: oasiis
# Date:  3/16
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1678970404.A.B01.html
#
#
# Title: [無/台北/大安] 古亭冷氣雅房 生活機能超方便
# Author: dogswang
# Date:  3/27
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1679852089.A.B1B.html
#
#
# Title: [女/台北/大安] 六張犁分租公寓5000雅房徵室友 機能佳
# Author: gemini0602
# Date:  3/31
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1680268136.A.F26.html
#
#
# Title: [無/台北/大安] 信義路三段雅房出租(近大安站)
# Author: smartvision
# Date:  6/07
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1686067582.A.A1C.html
#
#
# Title: [無/台北/大安] 家庭式雅房徵室友
# Author: castlepig
# Date:  6/13
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1686667694.A.2B0.html
#
#
# Title: [無/台北/大安] 近台大後門 師大夜市附近靜巷
# Author: bxzz
# Date:  6/20
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1687267734.A.A77.html
#
#
# Title: [女/台北/大安] 近捷運東門古亭站 師大台大旁
# Author: lecl
# Date:  7/19
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1689703309.A.C20.html
#
#
# Title: [女/台北/大安] ★★師大小木吉★★
# Author: holytwo
# Date:  7/28
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1690554671.A.309.html
#
#
# Title: [女/台北/大安] 捷運古亭站 近台大師大 含水電
# Author: sv
# Date:  8/08
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1691510043.A.488.html
#
#
# Title: [無/台北/大安] 泰順雅房 近師大,台大,大安公똠
# Author: ccharlie
# Date:  8/23
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1692773895.A.CE3.html
#
#
# Title: [徵/台北/大安] 東區上班愛乾淨女生找房
# Author: chichier
# Date:  9/01
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1693572623.A.173.html
#
#
# Title: [無/台北/大安] 泰順雅房 近師大,台大,大安公園
# Author: ccharlie
# Date:  9/03
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1693715588.A.D3B.html
#
#
# Title: [女/台北/大安] [和式雅房6500]近師大台大淡大
# Author: mycorrhiza
# Date:  9/03
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1693719385.A.075.html
#
#
# Title: [女/台北/大安] 近台電大樓捷運站 生活機能佳
# Author: act
# Date:  9/19
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1695129219.A.5AE.html
#
#
# Title: [無/台北/大安] 近師大、台大，寧靜雅房
# Author: marchipan
# Date: 10/10
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1696951116.A.7D0.html
#
#
# Title: [無/台北/大安] 近台大家庭式徵室友
# Author: jew710934
# Date: 10/13
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1697174606.A.F75.html
#
#
# Title: [女/台北/大安] 六張犁捷運走路三分鐘
# Author: mama520
# Date: 10/15
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1697371349.A.F54.html
#
#
# Title: [女/台北/大安] 7500元全包 近六張犁捷運
# Author: mama520
# Date: 11/09
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1699543647.A.2F5.html
#
#
# Title: [無/台北/大安] 近台大,大雅房獨立冷氣陽台洗衣機冰箱
# Author: ychenss
# Date: 11/13
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1699869287.A.19A.html
#
#
# Title: [女/台北/大安] 六張犁雅房出租
# Author: bloodycrux
# Date: 11/22
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1700641701.A.519.html
#
#
# Title: [女/台北/大安] 六張犁捷運站六分鐘雅房
# Author: hulamg
# Date: 11/25
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1700891664.A.7D8.html
#
#
# Title: [無/台北/大安] 近 北科大、光華商場、捷運忠
# Author: gfour
# Date: 12/09
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1702087555.A.8D3.html
#
#
# Title: [無/台北/大安] 忠孝敦化 女子質感寓所
# Author: qwert7788
# Date: 12/10
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1702193797.A.E7B.html
#
#
# Title: [無/台北/大安] 忠孝敦化2分鐘 分租雅房
# Author: qwert7788
# Date: 12/15
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1702612988.A.93B.html
#
#
# Title: [無/台北/大安]  近 北科大、光華商場、捷運忠
# Author: gfour
# Date: 12/17
# URL: https://www.ptt.cc/bbs/Rent_ya/M.1702772527.A.777.html

# %%
import csv
import json

# 指定CSV檔案名稱
csv_filename = 'matched_posts.csv'

# 寫入CSV檔
with open(csv_filename, 'w', encoding='utf-8', newline='') as csvfile:
    fieldnames = ['Title', 'Author', 'Date', 'URL']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    # 寫入CSV檔的標頭
    writer.writeheader()
    
    # 寫入匹配的帖子資料
    writer.writerows(matched_posts)

print(f'Saved matched posts to {csv_filename}')

# 指定JSON檔案名稱
json_filename = 'matched_posts.json'

# 寫入JSON檔
with open(json_filename, 'w', encoding='utf-8') as jsonfile:
    # 寫入匹配的帖子資料
    json.dump(matched_posts, jsonfile, ensure_ascii=False, indent=2)

print(f'Saved matched posts to {json_filename}')
# Out:
# Saved matched posts to matched_posts.csv
# Saved matched posts to matched_posts.json
